# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5],index=["a","b","c","d","e"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = [[1,444,"abc"],
        [2,555,"def"],
        [3,666,"ghi"],
        [4,444,"xyz"]]
df = pd.DataFrame(data,columns=['col1','col2','col3'],index=["a","b","c","d"])
display(df)
df.columns=['id','sal','dep']
df
# Out:
#    col1  col2 col3
# a     1   444  abc
# b     2   555  def
# c     3   666  ghi
# d     4   444  xyz
#    id  sal  dep
# a   1  444  abc
# b   2  555  def
# c   3  666  ghi
# d   4  444  xyz

# %%
df.dep.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['dep'] = df['dep'].astype('category')

# %%
df.dtypes
# Out:
# id        int64
# sal       int64
# dep    category
# dtype: object

# %%
cols_cat = ['id', 'sal']
df[cols_cat] = df[cols_cat].astype('int64')

df.dtypes
# Out:
# id        int64
# sal       int64
# dep    category
# dtype: object

# %%
data = [[1,444,"abc"],
        [2,555,"def"],
        [3,666,"ghi"],
        [4,444,"xyz"]]
df = pd.DataFrame(data,columns=['col1','col2','col3'],index=["a","b","c","d"])

# %%
df.head() #first 5
df.tail() #last 5
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='str')

# %%
classifications = df.col2.nunique()
classifications
# Out:
# 3

# %%
def get_range(df):
 x = df.max()
 y = df.min()
 return (x - y)
get_range(df.col1)
# Out:
# np.int64(3)

# %%
#very important 
df.col2.value_counts()
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      str
# dtypes: int64(2), str(1)
# memory usage: 300.0+ bytes

# %%
x1 = df.col2.values
# Out:
# array([444, 555, 666, 444])

# %%
df.values
# Out:
# array([[1, 444, 'abc'],
#        [2, 555, 'def'],
#        [3, 666, 'ghi'],
#        [4, 444, 'xyz']], dtype=object)

# %%
df.replace(555, 'sara')
# Out:
#    col1  col2 col3
# a     1   444  abc
# b     2  sara  def
# c     3   666  ghi
# d     4   444  xyz
